# %%
import datetime as dt
import pandas as pd
import numpy as np

# %%
dfs = pd.read_html("https://www.skysports.com/premier-league-table", header=0)
df = pd.DataFrame(dfs[0], columns=["Team"])
df.rename(columns={"Team": "Club"}, inplace=True)

# %%
df.to_csv("data/premier-league-teams-{}.csv".format(dt.datetime.now().year))

# %%
col_types = {'Age': np.int32, 'Potential': np.int32, 'Overall': np.int32}
ff18 = pd.read_csv('data/CompleteDataset.csv', usecols=['Name', 'Nationality', 'Club', 'Photo', 'Value', 'Age', 'Wage', 'Potential', 'Overall', 'Finishing', 'Penalties', 'Aggression', 'Crossing', 'Stamina', 'Dribbling'], dtype=col_types)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (23,40,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ukteams = ff18[ff18.Club.isin(df.Club)]
ukteams.head(11)
# Out:
#             Name  Age                                            Photo  \
# 5         De Gea   26  https://cdn.sofifa.org/sm/18/players/193080.png
# 6   K. De Bruyne   26  https://cdn.sofifa.org/sm/18/players/192985.png
# 8      E. Hazard   26  https://cdn.sofifa.org/sm/18/players/183277.png
# 15   T. Courtois   25  https://cdn.sofifa.org/sm/18/players/192119.png
# 17   David Silva   31  https://cdn.sofifa.org/sm/18/players/168542.png
# 18     S. Agüero   29  https://cdn.sofifa.org/sm/18/players/153079.png
# 21      N. Kanté   26  https://cdn.sofifa.org/sm/18/players/215914.png
# 22       H. Kane   23  https://cdn.sofifa.org/sm/18/players/202126.png
# 23      P. Pogba   24  https://cdn.sofifa.org/sm/18/players/195864.png
# 25    C. Eriksen   25  https://cdn.sofifa.org/sm/18/players/190460.png
# 27    A. Sánchez   28  https://cdn.sofifa.org/sm/18/players/184941.png
#
#    Nationality  Overall  Potential               Club    Value   Wage  \
# ...
